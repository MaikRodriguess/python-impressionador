# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests 
import json 

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()
print(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.662', 'low': '5.5975', 'varBid': '-0.0394', 'pctChange': '-0.7', 'bid': '5.5996', 'ask': '5.6013', 'timestamp': '1725551292', 'create_date': '2024-09-05 12:48:12'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '5.655', 'low': '5.635', 'varBid': '-0.02', 'pctChange': '-0.35', 'bid': '5.47', 'ask': '5.8', 'timestamp': '1725539520', 'create_date': '2024-09-05 09:32:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '4.1792', 'low': '4.1416', 'varBid': '-0.0223', 'pctChange': '-0.54', 'bid': '4.1405', 'ask': '4.1458', 'timestamp': '1725551284', 'create_date': '2024-09-05 12:48:04'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '7.435', 'low': '7.3679', 'varBid': '-0.044', 'pctChange': '-0.59', 'bid': '7.3669', 'ask': '7.3708', 'timestamp': '1725551248', 'create_date': '2024-09-05 12:47:28'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.0059', 'low': '0.0059', 'varBid': '0', 'pctChange': '0', 'bid': '0.0059', 'ask': '0.0059', 'timestamp': '1725551250', 'create_date': '2024-09-05 12:47:30'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '331048', 'low': '313333', 'varBid': '-13667', 'pctChange': '-4.16', 'bid': '314766', 'ask': '314886', 'timestamp': '1725551295', 'create_date': '2024-09-05 12:48:15'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '386.29', 'low': '365.05', 'varBid': '-8.06', 'pctChange': '-2.16', 'bid': '365.94', 'ask': '367.05', 'timestamp': '1725551197', 'create_date': '2024-09-05 12:46:37'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.2651', 'low': '6.2064', 'varBid': '-0.0249', 'pctChange': '-0.4', 'bid': '6.2075', 'ask': '6.2155', 'timestamp': '1725551282', 'create_date': '2024-09-05 12:48:02'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03937', 'low': '0.03891', 'varBid': '-0.0002', 'pctChange': '-0.51', 'bid': '0.03902', 'ask': '0.03904', 'timestamp': '1725551285', 'create_date': '2024-09-05 12:48:05'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '6.6734', 'low': '6.6074', 'varBid': '-0.0334', 'pctChange': '-0.5', 'bid': '6.6106', 'ask': '6.6191', 'timestamp': '1725551292', 'create_date': '2024-09-05 12:48:12'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.7991', 'low': '3.7652', 'varBid': '-0.0164', 'pctChange': '-0.43', 'bid': '3.7645', 'ask': '3.7693', 'timestamp': '1725551284', 'create_date': '2024-09-05 12:48:04'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.7955', 'low': '0.7895', 'varBid': '-0.0035', 'pctChange': '-0.44', 'bid': '0.7895', 'ask': '0.7898', 'timestamp': '1725551282', 'create_date': '2024-09-05 12:48:02'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.5322', 'low': '1.5103', 'varBid': '-0.0195', 'pctChange': '-1.28', 'bid': '1.5103', 'ask': '1.5109', 'timestamp': '1725551285', 'create_date': '2024-09-05 12:48:05'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '14115.36', 'low': '13297.44', 'varBid': '-565.65', 'pctChange': '-4.06', 'bid': '13342.48', 'ask': '13362.9', 'timestamp': '1725551291', 'create_date': '2024-09-05 12:48:11'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '3.19', 'low': '3.08', 'varBid': '-0.09', 'pctChange': '-2.86', 'bid': '3.08', 'ask': '3.08', 'timestamp': '1725551266', 'create_date': '2024-09-05 12:47:46'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.5608', 'low': '0.5428', 'varBid': '-0.0062', 'pctChange': ' ...

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
print('Dolar: {}'.format(cotacoes_dic['USD']['bid']))
print('Euro: {}'.format(cotacoes_dic['EUR']['bid']))
print('Bitcoin: {}'.format(cotacoes_dic['BTC']['bid']))
# Out:
# Dolar: 5.5996
# Euro: 6.2075
# Bitcoin: 314766

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
cotacoes_dolar30d = requests.get('https://economia.awesomeapi.com.br/json/USD-BRL/15')
cotacoes_dolar_dic = cotacoes_dolar30d.json()
# print(cotacoes_dolar_dic[0]['bid'])
lista_cotacoes_dolar = [float(item['bid']) for item in cotacoes_dolar_dic]
print(lista_cotacoes_dolar)
# Out:
# [5.599, 5.5996, 5.6001, 5.6009, 5.5989, 5.5999, 5.6005, 5.6009, 5.6019, 5.5995, 5.5996, 5.5994, 5.607, 5.6082, 5.6055]

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %%
cotacoes_btc = requests.get('https://economia.awesomeapi.com.br/json/daily/BTC-BRL/200?start_date=20240101&end_date=20240905')
cotacoes_btc_dic = cotacoes_btc.json()
lista_cotacoes_btc = [float(item['bid']) for item in cotacoes_btc_dic]
lista_cotacoes_btc.reverse()
print(lista_cotacoes_btc)
# Out:
# [259907.0, 259801.0, 257713.0, 256269.0, 254942.0, 259118.0, 260350.0, 271881.0, 283425.0, 312110.0, 306600.0, 311597.0, 310466.0, 316078.0, 340515.0, 319500.0, 329044.0, 333000.0, 342480.0, 343642.0, 347318.0, 361155.0, 357550.0, 366111.0, 359346.0, 349423.0, 328823.0, 344883.0, 342107.0, 314351.0, 340501.0, 328241.0, 321280.0, 323835.0, 338500.0, 348846.0, 350460.0, 347670.0, 356007.0, 353191.0, 351831.0, 359693.0, 354272.0, 333896.0, 335725.0, 347973.0, 346000.0, 351245.0, 353924.0, 362137.0, 348969.0, 357340.0, 356888.0, 347219.0, 341400.0, 347761.0, 332041.0, 338315.0, 323342.0, 336130.0, 335360.0, 341073.0, 340755.0, 347200.0, 342911.0, 332889.0, 334500.0, 328637.0, 327000.0, 325516.0, 328217.0, 316526.0, 304284.0, 304312.0, 320848.0, 326429.0, 326692.0, 321292.0, 317500.0, 313044.0, 323798.0, 315472.0, 315740.0, 318866.0, 325129.0, 317517.0, 338936.0, 335497.0, 342807.0, 343759.0, 341025.0, 360388.0, 359142.0, 357193.0, 352000.0, 354835.0, 359139.0, 356187.0, 359651.0, 354633.0, 353950.0, 357428.0, 355299.0, 356700.0, 358152.0, 360902.0, 372160.0, 376416.0, 373508.0, 373189.0, 373000.0, 374775.0, 373199.0, 363787.0, 369907.0, 360538.0, 357802.0, 358913.0, 361530.0, 361475.0, 356200.0, 354412.0, 355587.0, 350486.0, 351873.0, 346500.0, 328410.0, 338584.0, 335902.0, 339936.0, 338455.0, 341959.0, 352379.0, 353234.0, 353106.0, 337155.0, 316010.0, 313035.0, 321112.0, 308026.0, 312550.0, 316731.0, 314276.0, 314254.0, 316009.0, 323519.0, 332812.0, 353000.0, 354206.0, 352236.0, 355564.0, 370013.0, 375108.0, 378376.0, 376143.0, 368684.0, 370253.0, 372241.0, 384310.0, 385003.0, 387827.0, 377511.0, 374301.0, 368540.0, 376195.0, 354904.0, 351000.0, 338352.0, 312737.0, 319130.0, 312653.0, 343629.0, 337113.0, 338057.0, 326984.0, 326777.0, 331261.0, 323000.0, 318000.0, 323175.0, 327388.0, 322334.0, 322532.0, 323538.0, 335052.0, 337574.0, 352052.0, 353791.0, 355155.0, 346600.0, 329359.0, 330359.0, 335214.0, 334590.0, 333196.0, 325937.0, 334402.0, 325841.0, 327848.0, 313800.0]

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(lista_cotacoes_btc)
plt.show()
